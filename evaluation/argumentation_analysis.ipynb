# %% [markdown]
# # Argumentation Analysis
# This file is used to conduct a argumenation analysis.
#
# ## Analysis
# For the analyis each string was analysed individually. For each of the core components of Toulmins Argument Model the prompt was analyzed. Then the component was classified into one of the 3 classed chosen for this project (Present, Weak/Implicit, Absent).

# %%
from ArgumentationAnalysisResult import ArgumentationAnalysisResult, ToulminComponentClassifier

# %% [markdown]
# ### Results for Idea 1 (Good Idea)

# %%
MISTRAL_ANALYSES = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the project is innovative and promising.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Mentions addressing phishing attacks and practical solutions for user training.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Implicit assumption that addressing phishing is valuable.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Hints at the importance of cybersecurity but not elaborated.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions challenges like data privacy and market competition.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses softening language like 'slightly limited' and 'room for refinement'."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the project is novel, useful, and promising.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with alignment to course requirements and software development aspects.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that planning and development efforts validate the idea’s fit.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References to scalability and adaptability suggest relevance, not expanded.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions edge cases, monetization issues, and privacy concerns.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Says there is 'room for improvement', softening the overall judgment."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the project demonstrates novelty and usefulness.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with demand for cybersecurity and course fit.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes real-world applicability adds educational value.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Implied by the growing demand but lacks detailed support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions competition and technical challenges.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'could benefit' and 'seems appropriate' imply qualification."
    )
]


MISTRAL_ADVANCED_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the project presents a novel approach with market appeal.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with flexibility in IT security training and appeal to companies.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that flexibility and licensing model significantly impact appeal.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Suggests smaller organizations might struggle with access; not supported with evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights pricing limitations and platform complexity as concerns.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggestions like 'consider offering' and 'ensure' imply uncertainty."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that Phishntai is a novel and useful tool for cybersecurity training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim by referencing evaluation and improvement of employee skills.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes companies value and invest in employee IT skill development.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Hints at market trends but does not provide concrete evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions potential complexity challenges in simulation and training.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses cautious language such as 'consider offering' and 'to ensure completeness'."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a novel and useful cybersecurity training platform.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with growing need for IT security and focus on phishing simulations.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes rising cyber threats naturally increase product demand.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions the global cyber threat landscape without detailed support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies concerns with scalability, customization, and detailed implementation.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'might be needed' and 'should be considered' express reservation."
    )
]

DEEPSEEK_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the project is novel and meets a real-world need in cybersecurity education.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies the claim by referencing educational relevance and feasibility.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes addressing educational needs in cybersecurity is valuable without explaining why.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions market competition and enhancement strategies, but lacks solid evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes concerns about uniqueness, competition, and lack of depth in technical description.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses conditional language like 'could be enhanced' and 'might require', indicating qualification."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a novel and useful training platform.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this with the AI-generated phishing content and licensing model.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes personalization and AI increase training value but does not explain how.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions growing cyber threats and market demand without elaboration or data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions incomplete implementation specifics and possible issues with feasibility.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'could hinder' and 'could benefit' shows hedging and qualification."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the project is innovative and addresses real-world challenges.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies this through AI phishing simulations and course applicability.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes simulations help address security challenges, without detailing how.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Refers to real-world challenges and course fit but lacks supporting evidence or examples.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies weaknesses in deployment scalability and feedback mechanisms.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses language like 'could benefit' and 'might be too intricate', indicating caution."
    )
]

DEEPSEEK_ADVANCED_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is an innovative and useful cybersecurity training platform.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports the claim with AI-generated simulations, HR training use cases, and added features like videos.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes realistic simulations improve training outcomes without explicitly stating the logic.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions usefulness for various audiences and expanded features, but lacks concrete support or examples.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Cites issues like unclear pricing, AI reliability, ethical concerns, and need for further system integration.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'should be tested', 'could benefit' and 'needs clarity' express conditional judgment."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims that Phishntai is an innovative and useful solution for IT security education.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified through AI-simulated phishing, licensing model, and comprehensive training tools.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these elements directly translate into effectiveness and impact without elaboration.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Refers to sector-wide relevance and clear structure, but lacks evidentiary support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions complexity of integration and the importance of market differentiation.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'should be carefully managed' and 'promising viability' suggest cautious optimism."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that Phishntai is a novel and promising cybersecurity training concept.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this with its AI simulation strategy and use for companies and individuals.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes AI-generated simulations inherently enhance IT security training.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions the need for differentiation and expanded features, but does not give strong justification.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies issues with differentiation, licensing, feature gaps, and simulation quality.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses conditional suggestions like 'should focus' and 'could enhance', indicating implied limitations."
    )
]

MIXTRAL_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims Phishntai is useful and applicable due to IT security relevance.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this by citing digital security concerns and potential for differentiation through innovation.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that innovation in phishing simulations and training materials ensures usefulness.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Refers to growing cyber threats but lacks specific evidence or external support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions incomplete details on implementation, data privacy, and pricing.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language such as 'would be helpful' indicates conditional judgment and partial endorsement."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that Phishntai is a novel and useful solution for phishing defense.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim through references to AI-generated simulations and increased cyber threats.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes AI simulations improve effectiveness without directly justifying how.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions societal concern over data privacy and protection without deeper elaboration.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies gaps in technical details, privacy, and long-term viability.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses phrases like 'could benefit', indicating tentative suggestions."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a novel and useful project idea.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in the increasing demand for cyber security training and AI relevance.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes relevance of AI-driven simulations directly translates to training effectiveness.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions general trends like data protection without offering further justification.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights underestimated complexity and lack of detail in privacy and scalability.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggests more detail 'would benefit' the project, indicating partial or conditional stance."
    )
]


GEMMA3_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a novel and useful platform for cybersecurity training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with references to AI-generated simulations and course relevance.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes combining AI and license models improves training outcomes but does not explicitly justify why.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competition and market trends, but lacks evidence or comparative data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies incomplete implementation details and missing considerations like data privacy.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses conditional language like 'needs more detail' and 'consider focusing on a smaller scope'."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States the project has strong potential and usefulness despite limited uniqueness.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified by use of AI and license model to improve employee awareness.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these features improve cybersecurity effectiveness without explicit rationale.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Cites market competition and general need for training, but lacks supporting evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions insufficient detail in features and architecture, and competitive market pressure.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language such as 'could be strengthened' and 'recommendations include' implies reservation."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a viable training platform with high usefulness.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supported by reference to the critical need for cybersecurity and AI-enhanced simulations.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes AI adds educational value without clearly articulating how it does so.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions increasing cybersecurity demand and course fit without detailed justification.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights lack of detail in architecture, AI, data privacy, and reporting.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'needs more detail' and 'would benefit' imply limited certainty."
    )
]

GEMMA3_ADVANCED_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that Phishntai has strong potential in cybersecurity training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with timely focus, flexible licensing, and need for phishing training.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes timely relevance and flexible licensing increase effectiveness, without elaboration.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions fierce competition and value proposition but provides no supporting data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights execution complexity, need for robust metrics, and lacking proposal details.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'are crucial for success' and 'needs improvement' suggest partial endorsement."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims Phishntai is novel and has potential due to AI-powered simulations and licensing.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites AI integration and flexible licensing as differentiators.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these innovations enhance training effectiveness without clarifying mechanism.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References to phishing recognition rates and simplification needs lack data support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points to missing training content specifics and security tool integration.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Soft suggestions like 'prioritize' and 'focus on' imply conditional stance."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts strong potential due to cybersecurity training demand and AI novelty.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in AI-generated phishing simulations and current training demand.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes AI and training needs naturally lead to usefulness without further justification.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions monetization clarity and technical specifications but offers no evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Critiques lack of roadmap, technical detail, and clarity on monetization.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'needs careful consideration' and 'required before launch' imply moderate qualification."
    )
]

LLAMA3_1_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a solid and feasible project with market potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with AI phishing simulation, course fit, and relevance of cybersecurity.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes simulation and novelty justify platform usefulness without explicitly explaining connection.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competition and digital security needs, but lacks supporting data or comparative insights.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes existing competitors and the need for more detail on scalability and data security.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'would be beneficial' and 'may face competition' show cautious endorsement."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that Phishntai is useful and practical, with real-world relevance.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified with training simulations, licensing flexibility, and course alignment.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes training simulations and personalization lead to improved IT skills without detailing mechanism.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References existing services and data privacy needs but without supporting evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points to novelty limitations and lack of AI detail and data security planning.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Words like 'consider incorporating' and 'ensure a clear plan' signal mild qualification."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts Phishntai is a strong idea with high potential for IT skill training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim through real-world application, market viability, and comprehensive training.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that comprehensiveness and real-world relevance translate into impact.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions existing platforms and market context but lacks concrete evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights novelty concerns and suggests further differentiation through advanced features.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Recommendation language like 'consider differentiating' implies cautious suggestion."
    )
]

LLAMA3_1_ADVANCED_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai has good novelty, usefulness, and market potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with references to licensing flexibility and personalized training in response to cybersecurity concerns.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that these features meet market needs without explicitly justifying why.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References increasing concern over cybersecurity but lacks concrete evidence or examples.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions development complexity and missing detail on technical and business aspects.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'would make the project more comprehensive' indicates cautious suggestion."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims that Phishntai is a well-conceived and highly useful project.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified through AI phishing simulations and growing IT security importance.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes usefulness stems from AI-driven simulation without fully explaining the causal link.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions general security concerns but no data or specific examples.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes issues with complexity and accessibility for smaller users, suggesting pricing model adjustments.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses 'consider offering' and 'may be challenging', which express hedging."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai presents a novel but potentially limited market opportunity.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites AI-generated simulations and license model as basis for novelty and potential.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes novelty adds market value without clearly stating the link.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions existing competition without data or analysis to support impact.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Calls out uncertain market potential and suggests interactivity and scenario realism improvements.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Words like 'consider' and 'to improve' indicate qualified support."
    )
]


PHI_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims that Phishntai addresses the need for effective IT security training and has strong potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supported by AI phishing simulations and customizable training features.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes customization and AI integration enhance training outcomes without full justification.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions usability and competition, but no data or detailed support is provided.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Cites market competition and need for collaboration with cybersecurity experts as challenges.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'requires further refinement' show tentative support."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the project idea is innovative and widely applicable.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in the urgency of cybersecurity issues and broad applicability to companies and individuals.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes the urgency of cyber threats implies adoption, without articulating a clear mechanism.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References existing training programs as competition, but lacks detailed comparison.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions challenges around market competition and simulation access.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'promising but requires refinement' suggest a reserved stance."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the idea is highly innovative with real-world application.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supported by relevance to cybersecurity and real-world applicability.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that real-world alignment implies course and project value without explaining how.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competitors and general relevance but lacks concrete evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points to issues with scalability and user-friendliness affecting applicability.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'could benefit' and 'to make it more applicable' softens the claim."
    )
]


PHI_ADVANCED_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the project idea is novel and useful, addressing a critical cybersecurity need.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with broad applicability, increased threats, and skill development benefits.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes utility across industries due to security needs without explaining the mechanism.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions global trends like rising threats but lacks empirical support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Cites challenges in data privacy and user engagement as limitations.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses phrasing like 'could be improved' and 'some aspects may be complex', indicating conditional support."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that Phishntai is a novel and in-demand idea for cybersecurity training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified by platform features like phishing simulations and targeted training.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes simulations and training effectively improve IT skills without a detailed link.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Suggests unique offering but lacks supporting data or comparisons to other solutions.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions variable user needs, simulation complexity, and feature completeness as concerns.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'may face challenges' and 'could be improved' signal qualification."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims that the project is novel and widely useful for IT security training.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in use of AI-generated simulations and relevance to both companies and individuals.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes AI-based simulations translate into effective training outcomes without detailed explanation.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competing platforms and need for security training, but lacks depth.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Cites market competition and implementation complexity as potential hurdles.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses conditional phrasing like 'needs more thorough evaluation' to temper the claim."
    )
]

# %% [markdown]
# ### Results for Idea 2 (Bad Idea)

# %%
MISTRAL_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the discount finder app is novel, useful, and fits a course context well.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim with benefits such as saving money and smartphone ubiquity.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes combining features and mobile access leads to user value, without detailed reasoning.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competitive landscape but provides no data or comparisons.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies missing detail on data sourcing, edge cases, and stock changes.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'has promising potential' and 'requires careful planning' indicates some reservation."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app addresses a real-world problem and is suitable for project management courses.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with references to practical use, cost-conscious users, and course-related development tasks.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes practicality and development complexity add educational value without explaining the link.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions existing apps and user needs but lacks in-depth evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Raises technical challenges and missing details on features and monetization.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses softening terms like 'could benefit' and 'appropriate', showing cautious optimism."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that the app is moderately novel and applicable to real-world needs.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites consumer need for savings and increasing use of shopping apps.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes need and popularity justify market potential without direct linkage.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Refers to competition and scalability but lacks empirical support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions integration needs, edge cases, and long-term considerations.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'could benefit' and 'should be noted' imply conditional assessment."
    )
]

MISTRAL_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the discount finder app addresses a consumer need and is useful.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with features like optimized shopping lists and gasoline cost consideration.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes cost optimization and cross-store efficiency meet user needs without detailed reasoning.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions similar apps exist, but lacks comparative data or user insights.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies lack of novelty and recommends adding personalization and engagement features.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggestions like 'consider implementing' imply hedged evaluation."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app is useful and provides a novel element with gasoline cost consideration.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with benefit for budget-conscious users and decision-making enhancement.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes integrating fuel cost increases user value without substantiating how users weigh that tradeoff.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions dependency on supermarket partnerships and data accuracy without deeper elaboration.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes limitations around real-time data and dependence on external partnerships.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Use of 'potential', 'may be challenging', and similar phrasing signals limited certainty."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the app has market potential and is useful for cost-conscious consumers.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in aggregation of supermarket discounts and trip cost savings.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes aggregation and trip consideration improves user outcomes without justification.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions added value and user needs but no empirical or analytical backing.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points out complexity concerns and proposes improvements like online ordering.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggestive tone in 'consider addressing' and 'can be improved' shows cautious optimism."
    )
]

DEEPSEEK_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the discount finder app is functional and useful for real-world needs.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim by referencing discount savings and real-world applicability.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that saving money equates to high user value without elaborating user context.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions market interest and feature potential but no data or external support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Cites moderate novelty, complexity concerns, and lack of planning depth.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'could be reduced' and 'needs more detail' imply tentative conclusions."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that the discount finder app is well-conceived and practically applicable.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justifies with its usefulness in saving money and planning household shopping.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these functions are valuable to all users without clarifying assumptions.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions data integration complexity and feature suggestions but no empirical backing.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions need for added features and challenges in data integration.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Conditional language like 'could benefit' and 'remains feasible' weakens the certainty."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app is novel and useful for household shopping optimization.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in dual integration of discounts and planning features.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes combining discount and planning leads to consumer value without support.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competitors and educational value but no deeper justification.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights limitations due to competition and insufficient planning detail.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggestive phrasing like 'may require more' and 'lacks depth' reflects uncertainty."
    )
]

DEEPSEEK_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims that the app is novel, practical, and has strong market potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this by highlighting features like discount finding and fuel cost calculation.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes combining fuel cost and discount logic meets consumer needs, without detailed rationale.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions demographic relevance and backend needs, but lacks data support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points to complexity in data aggregation and lack of UI, testing, and marketing detail.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses tentative phrases like 'could be mitigated' and 'needs further details'."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the app is practical and has strong potential due to consumer interest in deals.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites features like coupon search and fuel cost assessment as core value.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these features add enough value without direct justification or context.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References common consumer needs and competition but lacks concrete evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Mentions oversimplified views, need for accuracy, and competitive pressure.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Cautions like 'could further strengthen it' and 'differentiation is crucial' show hedging."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app is novel and useful for finding cross-supermarket deals.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with core functionality of aggregating discounts across stores.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes aggregation is a key differentiator without specifying how or why.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions market niche and added features like sharing, but no external validation.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies limited market potential and missing implementation details.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Suggestive improvements and 'could enhance' phrasing show qualified stance."
    )
]

MIXTRAL_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the discount finder app is useful and promising for a course project.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports the claim with grocery savings, smartphone use, and course relevance.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes solving tangible consumer problems equates to strong project value without deeper reasoning.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions real-world value and competitive differentiation, but lacks evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Calls for more detail on uniqueness and challenge mitigation.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'room for improvement' and 'careful planning required' indicate cautious evaluation."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app is relatively novel and highly applicable to course context.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified through utility in saving money and enabling efficient shopping.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes fuel and discount awareness improves value without explaining user behavior impact.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions smartphone ubiquity and grocery savings trends, but lacks citations.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Points out incomplete coverage of data sourcing and real-time functionality.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'ensure to cover' and 'can be improved' show qualified support."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the app is novel, useful, and market-relevant due to its dual savings approach.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with integration of discounts and fuel savings as key functions.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes combining two cost-saving methods leads to user appeal without empirical basis.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Suggests uniqueness versus competition but lacks comparative data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies a need for greater detail on features and implementation tech stack.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Cautious phrases like 'could benefit from' and 'potential in the market' reflect hedging."
    )
]


GEMMA3_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the project idea is somewhat novel and a good fit for a course setting.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with the need to save money, addition of gas cost calculations, and software project relevance.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes gasoline cost differentiation adds substantial value without detailed justification.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competition and consumer problems but provides no external data or concrete proof.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Calls out issues in data sourcing, cost algorithms, and edge cases as major gaps.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses phrases like 'requires careful scope management' indicating limited certainty."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States the app has moderate novelty and good course applicability.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in gasoline cost inclusion and focus on saving for consumers.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes consumers will value fuel comparisons in discount apps without empirical support.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions industry crowding and feature possibilities but lacks supporting evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Details lacking in route algorithms, data integration, and UI strategy are noted.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Soft recommendations suggest caution rather than full confidence."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that while not groundbreaking, the project has useful application and course relevance.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports with real consumer need for discount apps and opportunity for diverse development skills.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes practical benefit from discount comparison without detailing user adoption factors.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions market saturation and technical expectations but lacks data or precedent.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies missing technical detail (data, algorithm, edge cases) as major weakness.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrasing like 'would greatly improve' and 'consider incorporating' signals hedged support."
    )
]

GEMMA3_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the discount finder app addresses a useful need with good market potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supported by practical value in optimizing shopping lists and cost tracking.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes users value fuel cost calculation as a meaningful differentiator without elaboration.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References similar apps and added features but lacks concrete evidence or comparison.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes high complexity and missing components such as user preferences and loyalty integration.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'would significantly enhance value' and 'recommendation' show cautious optimism."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts the project has market potential and meets a clear need.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in addressing discount tracking and adding gas cost calculation.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these features improve user outcomes without detailing usage behavior.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions similar apps and need for differentiation but lacks supporting data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies complexity in data integration and lack of UI and sourcing plans.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'prioritize' and 'focusing initially' reflect partial certainty."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app has decent market potential and a useful core idea.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this with focus on discounts and fuel calculation for shopping trips.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes integration of these features aligns with consumer behavior without empirical support.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions practical needs and complexity but lacks evidence-based justification.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights need for simplified MVP, data acquisition strategy, and API integration.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'somewhat limited' and 'prioritize' suggest a tentative stance."
    )
]

LLAMA3_1_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the discount finder app is useful and has development merit despite existing alternatives.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites usefulness in household shopping, smartphone adoption, and course fit.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes usefulness and mobile accessibility ensure relevance without elaboration.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References existing apps and need for further development, but lacks supporting evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes a need for detailed edge case handling and challenges.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Uses tentative phrasing like 'could benefit' and 'has merit'."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States the project idea is promising but lacks originality.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports usefulness through shopping list optimization and course complexity fit.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes optimizing shopping lists brings value without showing how it outperforms alternatives.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions building on existing concepts without contrasting or citing competitors.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Calls for more innovation to improve the project’s impact.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'with proper execution' and 'some adjustments' shows soft endorsement."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that the app idea has novelty and value, especially with the fuel cost feature.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified by the practical benefit of combining discounts and fuel costs.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes integration of fuel data enhances decision-making without supporting evidence.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions competitors but does not provide detailed market comparisons.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies potential issues with project simplicity and requirement detail.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'might be a concern' and 'should be specified' reflect uncertainty."
    )
]

LLAMA3_1_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app addresses a real need with moderate novelty and usefulness.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites gasoline cost calculation and household shopping as core value propositions.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these features will resonate with users without directly connecting them to improved outcomes.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions potential integrations and user value but without supporting data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies UX complexity and need for additional features like personalization.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language such as 'could be enhanced' indicates hedging."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that the app is novel and useful, with broad applicability.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this with relevance to budget-conscious consumers and ease of shopping.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes users prioritize convenience in discount tracking without elaboration.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions market size and additional features but lacks empirical support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Recommends improving features like supermarket coverage and personalization.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'to further improve' imply reserved confidence."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States that the idea is decent with moderate potential and needs refinement.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites utility in saving money and tracking discounts.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes these needs are enough to justify app use without deeper analysis.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions sector relevance and campaign targeting without elaboration.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights limitations in applicability and technical implementation.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Terms like 'requires refinement' suggest only partial endorsement."
    )
]

PHI_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States the app has moderate novelty and usefulness with promise in the market.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports claim by addressing consumer needs for finding supermarket discounts.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes broad consumer interest equates to strong market potential without specific evidence.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions potential customers but lacks market data or competitor analysis.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Calls for more practical implementation detail and real-world applicability.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Language like 'could be expanded upon' suggests partial confidence."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the project is innovative and feasible for course settings.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supported by its real-world application and manageability within time and resource constraints.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes innovation and feasibility justify educational value without elaborating how.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions existing apps as competition but lacks direct comparison or data.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies missing detail in cross-supermarket handling and security challenges.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'could use improvement' imply tentative endorsement."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Asserts that the discount finder is novel, useful, and marketable.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Grounded in the growing demand for money-saving tools and grocery apps.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes market demand translates into success without specifying user behavior or expectations.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions challenges in course applicability but does not justify how or why complexity is an issue.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Highlights course fit and complexity as barriers, suggesting simplification.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Recommendation to reduce complexity suggests hedged support."
    )
]

PHI_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS = [
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the app is innovative and useful for improving shopping efficiency.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Supports this through user discounts, revenue potential from supermarket partnerships, and wide appeal.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes that discount visibility leads to user engagement and revenue without substantiating the link.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions crowded market and app usage variability, but lacks external evidence.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Identifies weaknesses in market potential, competition, and user frequency.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Recommendations like 'consider adding' and 'ensure usability' suggest tentative optimism."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="States the app is a novel concept with strengths and potential.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Justified by money-saving utility and gasoline cost insights.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes cost-awareness influences user decisions without evidence.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="Mentions benefit for users, but lacks comparative or user data.",
        rebuttal=ToulminComponentClassifier.ABSENT,
        rebuttal_notes="No limitations or objections are raised in the evaluation.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Absence of strong commitment language indicates reserved judgment."
    ),
    ArgumentationAnalysisResult(
        claim=ToulminComponentClassifier.PRESENT,
        claim_notes="Claims the discount finder app is novel, useful, and widely appealing.",
        grounds=ToulminComponentClassifier.PRESENT,
        grounds_notes="Cites utility in grocery savings and potential added features like meal planning.",
        warrant=ToulminComponentClassifier.IMPLICT_WEAK,
        warrant_notes="Assumes users value integrated shopping tools without justifying user behavior or market gap.",
        backing=ToulminComponentClassifier.IMPLICT_WEAK,
        backing_notes="References market potential and usefulness without empirical support.",
        rebuttal=ToulminComponentClassifier.PRESENT,
        rebuttal_notes="Notes development complexity and need for functional completeness.",
        qualifier=ToulminComponentClassifier.IMPLICT_WEAK,
        qualifier_notes="Phrases like 'could be very useful' and 'with some refinements' signal partial endorsement."
    )
]

# %% [markdown]
# ## Display of Results
# In the following the method to display the results will be shown.

# %%
import matplotlib.pyplot as plt
import numpy as np
from ArgumentationAnalysisResult import COMPONENT_NAMES

# Set global font sizes
plt.rcParams.update({
    'axes.titlesize': 18,
    'axes.labelsize': 16,
    'xtick.labelsize': 18,
    'ytick.labelsize': 16,
    'legend.fontsize': 14,
    'legend.title_fontsize': 16
})

# Components in order

labels = ["PRESENT", "IMPLICT_WEAK", "ABSENT"]

# Prepare aggregated data
model_component_stats = {}
component_names = [str(component).lower() for component in COMPONENT_NAMES]

classification_score = {
    "PRESENT": 3,
    "IMPLICT_WEAK": 2,
    "ABSENT": 1
}

def plot_argumentation_anaylisis_results(all_models_data):
    average_scores = {component: [] for component in component_names}
    model_names = list(all_models_data.keys())

    for component in component_names:
        for model in model_names:
            scores = []
            for result in all_models_data[model]:
                status = getattr(result, component)
                scores.append(classification_score[status.name])
            average = sum(scores) / len(scores) if scores else 0
            average_scores[component].append(average)
        model_names = list(all_models_data.keys())

    n_models = len(model_names)
    n_components = len(COMPONENT_NAMES)
    bar_width = 0.12
    index = np.arange(n_models)

    # Reuse average_scores from earlier
    fig, ax = plt.subplots(figsize=(10, 6))
    colors = plt.cm.tab10(np.linspace(0, 1, n_components))

    # Adjust bar positions and draw bars for each Toulmin component
    for i, component in enumerate(component_names):
        bar_positions = index + (i - n_components / 2) * bar_width + bar_width / 2
        ax.bar(bar_positions, average_scores[component], width=bar_width, label=f"{component.capitalize()}", color=colors[i])

    ax.set_xlabel("")
    ax.set_ylabel("Average Dimension Score")
    ax.set_title("Per-Dimension Averages per Model (Toulmin Analysis)")
    ax.set_xticks(index)
    ax.set_xticklabels(model_names)
    ax.legend(title="Component", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xticks(rotation=45)  # or rotation=30 for shallower angle, 60 for steeper
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Results of 1. Idea (Good/Simple)

# %%
all_models_data = {
    "Mistral": MISTRAL_ANALYSES,
    "Mixtral": MIXTRAL_ANALYSIS_RESULTS,
    "Deepseek-R1": DEEPSEEK_ANALYSIS_RESULTS,
    "Gemma3": GEMMA3_ANALYSIS_RESULTS,
    "Llama3.1": LLAMA3_1_ANALYSIS_RESULTS,
    "Phi": PHI_ANALYSIS_RESULTS,
}

plot_argumentation_anaylisis_results(all_models_data)

# %% [markdown]
# ### Results of 1. Idea (Good/Advanced)

# %%
all_models_data = {
    "Mistral": MISTRAL_ADVANCED_ANALYSIS_RESULTS,
    "Deepseek-R1": DEEPSEEK_ADVANCED_ANALYSIS_RESULTS,
    "Gemma3": GEMMA3_ADVANCED_ANALYSIS_RESULTS,
    "Llama3.1": LLAMA3_1_ADVANCED_ANALYSIS_RESULTS,
    "Phi": PHI_ADVANCED_ANALYSIS_RESULTS,
}

plot_argumentation_anaylisis_results(all_models_data)

# %% [markdown]
# ### Results of 2. Idea (Bad/Simple)

# %%
all_models_data = {
    "Mistral": MISTRAL_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Mixtral": MIXTRAL_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Deepseek-R1": DEEPSEEK_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Gemma3": GEMMA3_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Llama3.1": LLAMA3_1_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Phi": PHI_EVALUATIONS_2_ANALYSIS_RESULTS,
}

plot_argumentation_anaylisis_results(all_models_data)

# %% [markdown]
# ### Results of 2. Idea (Bad/Advanced)

# %%
all_models_data = {
    "Mistral": MISTRAL_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Deepseek-R1": DEEPSEEK_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Gemma3": GEMMA3_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Llama3.1": LLAMA3_1_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS,
    "Phi": PHI_ADVANCED_EVALUATIONS_2_ANALYSIS_RESULTS,
}

plot_argumentation_anaylisis_results(all_models_data)
